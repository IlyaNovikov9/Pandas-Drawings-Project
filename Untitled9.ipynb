# %%
import pandas as pd
import numpy as np
import datetime
import math
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import statistics
from keras.preprocessing import image
import matplotlib.animation
import warnings
warnings.filterwarnings("ignore")

# %%
image= Image.open("C:\\Users\\hila\\Desktop\\train\\train\\7558\\SimpleTest\\12.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1381x925 at 0x1B69F93BB80>

# %%
for d in os.listdir("C:\\Users\\hila\\Desktop\\train\\train"):
    if (not d.startswith('.')):
        d_path = os.path.join("C:\\Users\\hila\Desktop\\train\\train\\{}\SimpleTest")
        for f in os.listdir(d_path.format(d)):
            if(f.endswith('.csv') and f != "Test Time Log.csv"):
                f_path = d_path.format(d)
                data = pd.read_csv(f_path + '/' + f)
                #print(data)
                data['Color'] = 0
                data.dropna(axis = 0, inplace = True)
                data = data.astype({'X' : float})
                data.to_csv(f_path + '/' + f, index=False)
                distance=[None]
                distance.extend([math.sqrt(math.pow((data.iloc[i]['X']-data.iloc[i-1]['X']),2)+math.pow((data.iloc[i]['Y']-data.iloc[i-1]['Y']),2)) for i in range(1,len(data))])
                data['Distance']= distance
                data.Distance[0]=0
data
# Out:
#             X           Y  Pressure   TiltX   TiltY           Time  Color  \
# 0    687.5625  369.360000  0.172363  6446.0  9508.0  00:04.2463257      0
# 1    687.5625  369.360000  0.183105  6446.0  9508.0  00:04.2621921      0
# 2    687.5625  369.360000  0.242920  6446.0  9508.0  00:04.2779238      0
# 3    687.5625  369.360000  0.307373  6446.0  9508.0  00:04.2932756      0
# 4    687.5625  369.613333  0.364502  6446.0  9508.0  00:04.2932756      0
# ..        ...         ...       ...     ...     ...            ...    ...
# 657  484.3575  518.826667  1.000000  7669.0  9505.0  00:19.2224928      0
# 658  485.3550  518.446667  0.990967  7654.0  9461.0  00:19.2384940      0
# 659  485.9250  517.940000  0.980713  7643.0  9426.0  00:19.2384940      0
# 660  486.2100  517.560000  0.960205  7638.0  9406.0  00:19.2537583      0
# 661  487.0650  515.786667  0.665771  7629.0  9375.0  00:19.2537583      0
#
#      Distance
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.253333
# ..        ...
# 657  1.304113
# 658  1.067430
# 659  0.762634
# 660  0.475000
# 661  1.968689
#
# [662 rows x 8 columns]

# %%
#question1
def pen_raises(path):
    lifts=0
    for i in range(len(data)-1):
        if data.Distance[i] > 0:
            lifts=lifts+1
    return lifts
def howMuchLines():
    lines=0
    slant = (data['Y'][1] - data['Y'][0]) / (data['X'][1] - data['X'][0] )
    for index in (data.index[:-1]):
        slantemp = (data['Y'][index+1] - data['Y'][index]) / (data['X'][index+1] - data['X'][index] )
        if(slantemp-slant<0.1):
            same=0
        else:
            lines+=1
            slant=slantemp
    return(lines)

def mission123(path):
    count=0
    for f in os.listdir(path):
        file_path = os.path.join(path+'\\'+f)
        if(f.split(".")[1] == "csv" and f != "Test Time Log.csv"):
            slant0 = (data['Y'][1] - data['Y'][0]) / (data['X'][1] - data['X'][0] )
            data = pd.read_csv(file_path)
            dots=0
            pressure_sum=0
            pressure_avg=0
            length = 0
            lines = 0
            dicte={}
            lst = []
            count=count+1
            flag = False
            lst.append([count])
            for index in (data.index[:-1]):
                slantemp = (data['Y'][index+1] - data['Y'][index]) / (data['X'][index+1] - data['X'][index])
                if(abs(slantemp - slant0) < 0.2):
                    flag = True
                    dots += 1
                    pressure_sum += data['Pressure'][index]
                    length += math.sqrt(math.pow(data["X"][index] - data["X"][index+1],2) + math.pow(data["Y"][index] - data["Y"][index+1],2))
                    #print(length)
                else:
                    if(flag):
                        dots += 1
                        lines += 1
                        pressure_sum += data['Pressure'][index]
                        pressure_avg = pressure_sum / dots
                        dicte={'length':length,'pesssure_avg':pressure_avg,'lines':lines}
                        lst.append([dicte])
                    dots = 0
                    pressure_sum = 0
                    length = 0
                    flag = False
                    slant0 = slantemp
            data.to_csv(file_path, index=False)
            pprint.pprint(lst)

# %%
#howMuchLines()
#print(pen_raises("C:\\Users\\hila\\Desktop\\train\\train\\7558\\SimpleTest"))
print(mission123(os.path.join("C:\\Users\\hila\\Desktop\\train\\train\\7558\\SimpleTest")))
# Out:
# [[1],
#  [{'length': 22.81046299810178,
#    'lines': 1,
#    'pesssure_avg': 0.17237284779548642}],
#  [{'length': 6.776788811475852,
#    'lines': 2,
#    'pesssure_avg': 0.3353983809550603}],
#  [{'length': 108.5095705924766,
#    'lines': 3,
#    'pesssure_avg': 0.42667196377327565}]]
# [[2],
#  [{'length': 6.090655937921077,
#    'lines': 1,
#    'pesssure_avg': 0.3399150470892587}],
#  [{'length': 33.416141784012794,
#    'lines': 2,
#    'pesssure_avg': 0.545305562019348}],
#  [{'length': 216.36778726059538,
#    'lines': 3,
#    'pesssure_avg': 0.8441983461380006}],
#  [{'length': 87.94877781806392,
#    'lines': 4,
#    'pesssure_avg': 0.8795283370547824}],
#  [{'length': 11.242806473323318,
#    'lines': 5,
#    'pesssure_avg': 0.3215228468179705}],
#  [{'length': 7.635985679640066,
#    'lines': 6,
#    'pesssure_avg': 0.3559471964836125}],
#  [{'length': 199.4366928481863,
#    'lines': 7,
#    'pesssure_avg': 0.6244674309303886}],
#  [{'length': 21.58410255325171, 'lines': 8, 'pesssure_avg': 0.782467380166054}],
#  [{'length': 5.536099491861494,
#    'lines': 9,
#    'pesssure_avg': 0.7920500487089158}],
#  [{'length': 1.8394035416646926,
#    'lines': 10,
#    'pesssure_avg': 0.675776302814484}],
#  [{'length': 2.0706268813049364,
#    'lines': 11,
#    'pesssure_avg': 0.3250629380345345}],
#  [{'length': 9.702775867402297,
#    'lines': 12,
#    'pesssure_avg': 0.3571457361633127}],
#  [{'length': 1.1392526030334449,
#    'lines': 13,
#    'pesssure_avg': 0.652826726436615}],
#  [{'length': 2.8103932616897365,
#    'lines': 14,
#    'pesssure_avg': 0.725825905799866}],
#  [{'length': 12.123639196862065,
#    'lines': 15,
#    'pesssure_avg': 0.6421192628996713}],
#  [{'length': 23.117938620187704,
#    'lines': 16,
#    'pesssure_avg': 0.6812939703464507}],
#  [{'length': 3.207226079453614,
#    'lines': 17,
#    'pesssure_avg': 0.4104727605978647}],
#  [{'length': 2.4435553123438325,
#    'lines': 18,
#    'pesssure_avg': 0.492586652437846}],
#  [{'length': 2.435450622852555,
#    'lines': 19,
#    'pesssure_avg': 0.5573662916819256}],
#  [{'length': 2.44990840630547,
#    'lines': 20,
#    'pesssure_avg': 0.6280053853988646}],
#  [{'length': 10.216712098062992,
#    'lines': 21,
#    'pesssure_avg': 0.7056665505681717}],
#  [{'length': 0.979569269940753,
#    'lines': 22,
#    'pesssure_avg': 0.721431314945221}],
#  [{'length': 1.1171290872652986,
#    'lines': 23,
#    'pesssure_avg': 0.7456015646457675}],
#  [{'length': 4.951401376215729,
#    'lines': 24,
#    'pesssure_avg': 0.6551867922147117}],
#  [{'length': 4.7736591697795685,
#    'lines': 25,
#    'pesssure_avg': 0.7614099383354188}],
#  [{'length': 1.5630938603351427,
#    'lines': 26,
#    'pesssure_avg': 0.789059281349182}],
#  [{'length': 0.802123232769083,
#    'lines': 27,
#    'pesssure_avg': 0.8142061531543735}],
#  [{'length': 4.065563848920471,
#    'lines': 28,
#    'pesssure_avg': 0.829180339972178}],
#  [{'length': 4.547347544608142,
#    'lines': 29,
#    'pesssure_avg': 0.8438289960225424}],
#  [{'length': 4.080877975435084,
#    'lines': 30,
#    'pesssure_avg': 0.855710685253143}],
#  [{'length': 9.801468370581764,
#    'lines': 31,
#    'pesssure_avg': 0.856687247753143}],
#  [{'length': 277.5011114551509,
#    'lines': 32,
#    'pesssure_avg': 0.460318922996521}],
#  [{'length': 0.7496798558978329,
#    'lines': 33,
#    'pesssure_avg': 0.16803743441899632}],
#  [{'length': 0.666127087671346,
#    'lines': 34,
#    'pesssure_avg': 0.480582892894745}],
#  [{'length': 1.3488045512273719,
#    'lines': 35,
#    'pesssure_avg': 0.6093690395355225}],
#  [{'length': 7.648819442470174,
#    'lines': 36,
#    'pesssure_avg': 0.7015579462051391}],
#  [{'length': 53.122439750128805,
#    'lines': 37,
#    'pesssure_avg': 0.7153451283063207}],
#  [{'length': 0.3070694149494955,
#    'lines': 38,
#    'pesssure_avg': 0.09214923158287999}],
#  [{'length': 0.6163925579504126,
#    'lines': 39,
#    'pesssure_avg': 0.2744029834866525}],
#  [{'length': 0.8572747651950937,
#    'lines': 40,
#    'pesssure_avg': 0.40807202458381653}],
#  [{'length': 7.697655368684794,
#    'lines': 41,
#    'pesssure_avg': 0.6739858984947208}],
#  [{'length': 0.7828764694282597,
#    'lines': 42,
#    'pesssure_avg': 0.710200667381287}],
#  [{'length': 4.234624961217149,
#    'lines': 43,
#    'pesssure_avg': 0.711177229881287}],
#  [{'length': 3.4857432189530364,
#    'lines': 44,
#    'pesssure_avg': 0.47075609117746353}],
#  [{'length': 4.000308328752832,
#    'lines': 45,
#    'pesssure_avg': 0.5738867123921714}],
#  [{'length': 3.436151998160445,
#    'lines': 46,
#    'pesssure_avg': 0.238920676211516}],
#  [{'length': 0.614138829899147,
#    'lines': 47,
#    'pesssure_avg': 0.431754022836685}],
#  [{'length': 4.928459708308312,
#    'lines': 48,
#    'pesssure_avg': 0.6387273967266083}],
#  [{'length': 0.5421881677205804,
#    'lines': 49,
#    'pesssure_avg': 0.642816841602325}],
#  [{'length': 7.235408342399386,
#    'lines': 50,
#    'pesssure_avg': 0.642816841602325}]]
# [[3],
#  [{'length': 1.7912812602778816,
#    'lines': 1,
#    'pesssure_avg': 0.08897535502910606}],
#  [{'length': 5.246411614157738,
#    'lines': 2,
#    'pesssure_avg': 0.5009689480066299}],
#  [{'length': 5.30430627249333, 'lines': 3, 'pesssure_avg': 0.6297143896420799}],
#  [{'length': 1.169285496003706,
#    'lines': 4,
#    'pesssure_avg': 0.6849317252635955}],
#  [{'length': 10.39694090822482,
#    'lines': 5,
#    'pesssure_avg': 0.7177691062291464}],
#  [{'length': 10.302519498177238,
#    'lines': 6,
#    'pesssure_avg': 0.7548302412033083}],
#  [{'length': 2.462193507687983,
#    'lines': 7,
#    'pesssure_avg': 0.7741664946079255}],
#  [{'length': 2.3411349444438097,
#    'lines': 8,
#    'pesssure_avg': 0.8015106320381165}],
#  [{'length': 0.8491487546417694,
#    'lines': 9,
#    'pesssure_avg': 0.804928660392761}],
#  [{'length': 3.115987587494522,
#    'lines': 10,
#    'pesssure_avg': 0.808834969997406}],
#  [{'length': 1.5550893441432245,
#    'lines': 11,
#    'pesssure_avg': 0.808834969997406}],
#  [{'length': 2.9813238247503295,
#    'lines': 12,
#    'pesssure_avg': 0.8101370930671693}],
#  [{'length': 13.167822014951419,
#    'lines': 13,
#    'pesssure_avg': 0.808041512966156}],
#  [{'length': 15.073802314813836,
#    'lines': 14,
#    'pesssure_avg': 0.829098954796791}],
#  [{'length': 13.259493640817759,
#    'lines': 15,
#    'pesssure_avg': 0.8554665644963584}],
#  [{'length': 7.020143059975158,
#    'lines': 16,
#    'pesssure_avg': 0.8947737812995912}],
#  [{'length': 1.4904360998560577,
#    'lines': 17,
#    'pesssure_avg': 0.906492710113525}],
#  [{'length': 12.450188336886475,
#    'lines': 18,
#    'pesssure_avg': 0.9141832689444224}],
#  [{'length': 1.665317719179224,
#    'lines': 19,
#    'pesssure_avg': 0.921141386032104}],
#  [{'length': 3.233828832307858,
#    'lines': 20,
#    'pesssure_avg': 0.9340810328722003}],
#  [{'length': 1.5416561295178735,
#    'lines': 21,
#    'pesssure_avg': 0.938963919878006}],
#  [{'length': 1.1501547902216285,
#    'lines': 22,
#    'pesssure_avg': 0.940917074680328}],
#  [{'length': 1.460361156826442,
#    'lines': 23,
#    'pesssure_avg': 0.941893637180328}],
#  [{'length': 17.693340244379563,
#    'lines': 24,
#    'pesssure_avg': 0.9512796401977537}],
#  [{'length': 42.40109978785381,
#    'lines': 25,
#    'pesssure_avg': 0.9824894236193763}],
#  [{'length': 23.727438978888706,
#    'lines': 26,
#    'pesssure_avg': 0.9754111766815188}],
#  [{'length': 18.38842407885304,
#    'lines': 27,
#    'pesssure_avg': 0.969091316064199}],
#  [{'length': 1.074097654785989,
#    'lines': 28,
#    'pesssure_avg': 0.46544593572616555}],
#  [{'length': 0.4212957616359745,
#    'lines': 29,
#    'pesssure_avg': 0.1696650609374045}],
#  [{'length': 10.566292767598087,
#    'lines': 30,
#    'pesssure_avg': 0.7041580826044083}],
#  [{'length': 6.317022289774168,
#    'lines': 31,
#    'pesssure_avg': 0.7700160443782811}],
#  [{'length': 3.606095462289892,
#    'lines': 32,
#    'pesssure_avg': 0.7868619859218595}],
#  [{'length': 5.606645059439952,
#    'lines': 33,
#    'pesssure_avg': 0.7998016277949013}],
#  [{'length': 2.2615735890558586,
#    'lines': 34,
#    'pesssure_avg': 0.814206143220266}],
#  [{'length': 0.307069414949593,
#    'lines': 35,
#    'pesssure_avg': 0.817624151706696}],
#  [{'length': 1.8438432457920104,
#    'lines': 36,
#    'pesssure_avg': 0.8241346776485442}],
#  [{'length': 1.1109054784658037,
#    'lines': 37,
#    'pesssure_avg': 0.03880369290709495}],
#  [{'length': 1.3427833922569112,
#    'lines': 38,
#    'pesssure_avg': 0.23721166948477435}],
#  [{'length': 0.4342617312115482,
#    'lines': 39,
#    'pesssure_avg': 0.4977950751781465}],
#  [{'length': 2.7408112511656917,
#    'lines': 40,
#    'pesssure_avg': 0.5588311751683553}],
#  [{'length': 10.026113284183307,
#    'lines': 41,
#    'pesssure_avg': 0.6892652809619902}],
#  [{'length': 19.80968827918622,
#    'lines': 42,
#    'pesssure_avg': 0.7847867548465728}],
#  [{'length': 2.0341431596301898,
#    'lines': 43,
#    'pesssure_avg': 0.8308079540729525}],
#  [{'length': 8.89762295098217,
#    'lines': 44,
#    'pesssure_avg': 0.8382950491375392}],
#  [{'length': 1.1502459529411189,
#    'lines': 45,
#    'pesssure_avg': 0.846433202425639}],
#  [{'length': 0.2835933886187671,
#    'lines': 46,
#    'pesssure_avg': 0.852292656898499}],
#  [{'length': 1.0740976547858108,
#    'lines': 47,
#    'pesssure_avg': 0.8550270915031429}],
#  [{'length': 0.7162802346670432,
#    'lines': 48,
#    'pesssure_avg': 0.0530861373990774}],
#  [{'length': 1.6803199505486839,
#    'lines': 49,
#    'pesssure_avg': 0.638422211011251}],
#  [{'length': 13.482940802950662,
#    'lines': 50,
#    'pesssure_avg': 0.7317260454098385}],
#  [{'length': 0.5887787260304729,
#    'lines': 51,
#    'pesssure_avg': 0.7553673684597015}],
#  [{'length': 13.051520693291756,
#    'lines': 52,
#    'pesssure_avg': 0.7524376332759857}],
#  [{'length': 2.219372335899433,
#    'lines': 53,
#    'pesssure_avg': 0.7661097049713135}],
#  [{'length': 2.1091102630545895,
#    'lines': 54,
#    'pesssure_avg': 0.7653772532939911}],
#  [{'length': 5.17934817452221,
#    'lines': 55,
#    'pesssure_avg': 0.7562044177736554}],
#  [{'length': 0.3330635438362662,
#    'lines': 56,
#    'pesssure_avg': 0.758297085762024}],
#  [{'length': 0.3330635438362662,
#    'lines': 57,
#    'pesssure_avg': 0.759273648262024}],
#  [{'length': 1.4489221204396874,
#    'lines': 58,
#    'pesssure_avg': 0.763179957866669}],
#  [{'length': 2.567507340303274,
#    'lines': 59,
#    'pesssure_avg': 0.7651331126689911}],
#  [{'length': 2.5035214836569235,
#    'lines': 60,
#    'pesssure_avg': 0.789547562599182}],
#  [{'length': 6.311812149632457,
#    'lines': 61,
#    'pesssure_avg': 0.8249484896659854}],
#  [{'length': 0.49681203328587886,
#    'lines': 62,
#    'pesssure_avg': 0.843015193939209}],
#  [{'length': 0.28359338861914707,
#    'lines': 63,
#    'pesssure_avg': 0.8564431369304655}],
#  [{'length': 1.5308246876789244,
#    'lines': 64,
#    'pesssure_avg': 0.5103684961795805}],
#  [{'length': 0.8192279973273497,
#    'lines': 65,
#    'pesssure_avg': 0.621698349714279}],
#  [{'length': 1.7780501145631329,
#    'lines': 66,
#    'pesssure_avg': 0.7175738096237183}],
#  [{'length': 1.7221539516175326,
#    'lines': 67,
#    'pesssure_avg': 0.743973950544993}],
#  [{'length': 8.562050214692938,
#    'lines': 68,
#    'pesssure_avg': 0.7702601701021192}],
#  [{'length': 10.53217703076514,
#    'lines': 69,
#    'pesssure_avg': 0.7849785940987724}],
#  [{'length': 2.9532990650753135,
#    'lines': 70,
#    'pesssure_avg': 0.7902800142765045}],
#  [{'length': 1.519003470712048,
#    'lines': 71,
#    'pesssure_avg': 0.793209731578827}],
#  [{'length': 3.156342670675378,
#    'lines': 72,
#    'pesssure_avg': 0.793209731578827}],
#  [{'length': 0.22342581745281856,
#    'lines': 73,
#    'pesssure_avg': 0.791256606578827}],
#  [{'length': 15.06897129957376,
#    'lines': 74,
#    'pesssure_avg': 0.7545303106307983}],
#  [{'length': 1.8958309273589293,
#    'lines': 75,
#    'pesssure_avg': 0.7654993534088135}],
#  [{'length': 16.628102933847504,
#    'lines': 76,
#    'pesssure_avg': 0.7612712003967977}],
#  [{'length': 23.02031771320716,
#    'lines': 77,
#    'pesssure_avg': 0.7823668507968679}],
#  [{'length': 12.44094106163688,
#    'lines': 78,
#    'pesssure_avg': 0.8284537196159363}],
#  [{'length': 1.4195908606878938,
#    'lines': 79,
#    'pesssure_avg': 0.8460263013839723}],
#  [{'length': 0.3723763624224361,
#    'lines': 80,
#    'pesssure_avg': 0.8452124893665315}],
#  [{'length': 0.7025983154220464,
#    'lines': 81,
#    'pesssure_avg': 0.847531855106354}],
#  [{'length': 0.9479154636790099,
#    'lines': 82,
#    'pesssure_avg': 0.8452124893665315}],
#  [{'length': 0.6341340949219281,
#    'lines': 83,
#    'pesssure_avg': 0.8455787003040315}],
#  [{'length': 0.5370488273929388,
#    'lines': 84,
#    'pesssure_avg': 0.8494850099086765}],
#  [{'length': 1.8181731111546537,
#    'lines': 85,
#    'pesssure_avg': 0.18431372195482248}],
#  [{'length': 7.99590764990603,
#    'lines': 86,
#    'pesssure_avg': 0.6307072639465331}],
#  [{'length': 8.856973568876297,
#    'lines': 87,
#    'pesssure_avg': 0.7096513211727142}],
#  [{'length': 1.0373205122112588,
#    'lines': 88,
#    'pesssure_avg': 0.724849343299866}],
#  [{'length': 2.9723550863880552,
#    'lines': 89,
#    'pesssure_avg': 0.729976356029511}],
#  [{'length': 10.034453192424074,
#    'lines': 90,
#    'pesssure_avg': 0.7364868720372519}],
#  [{'length': 2.512471029531061, 'lines': 91, 'pesssure_avg': 0.74267186721166}],
#  [{'length': 2.1637114561869115,
#    'lines': 92,
#    'pesssure_avg': 0.763424098491669}],
#  [{'length': 0.23551149041264674,
#    'lines': 93,
#    'pesssure_avg': 0.765377283096313}],
#  [{'length': 0.37237636242185734,
#    'lines': 94,
#    'pesssure_avg': 0.765377283096313}],
#  [{'length': 3.2746577639613945,
#    'lines': 95,
#    'pesssure_avg': 0.8228000283241272}],
#  [{'length': 0.6513925968176946,
#    'lines': 96,
#    'pesssure_avg': 0.8643778264522555}],
#  [{'length': 4.64443872268784,
#    'lines': 97,
#    'pesssure_avg': 0.8826642155647277}],
#  [{'length': 1.5657529388558467,
#    'lines': 98,
#    'pesssure_avg': 0.9025864005088804}],
#  [{'length': 14.25589479761427,
#    'lines': 99,
#    'pesssure_avg': 0.9203479140996933}],
#  [{'length': 8.800043585029533,
#    'lines': 100,
#    'pesssure_avg': 0.9323022621018546}],
#  [{'length': 3.054866877073227,
#    'lines': 101,
#    'pesssure_avg': 0.9361155430475874}],
#  [{'length': 0.44685163490619983,
#    'lines': 102,
#    'pesssure_avg': 0.938231468200684}],
#  [{'length': 0.4739577318399597,
#    'lines': 103,
#    'pesssure_avg': 0.9369293848673507}]]
# [[4],
#  [{'length': 3.6987302633426022,
#    'lines': 1,
#    'pesssure_avg': 0.3240863680839535}],
#  [{'length': 18.888351226474462,
#    'lines': 2,
#    'pesssure_avg': 0.389964650074641}],
#  [{'length': 55.413809519014364,
#    'lines': 3,
#    'pesssure_avg': 0.4552163004875184}],
#  [{'length': 66.41699406330625,
#    'lines': 4,
#    'pesssure_avg': 0.49676966071128836}],
#  [{'length': 23.781873625268634,
#    'lines': 5,
#    'pesssure_avg': 0.5019455328583717}],
#  [{'length': 4.208017660442385,
#    'lines': 6,
#    'pesssure_avg': 0.11900511384010301}],
#  [{'length': 4.152622587223984, 'lines': 7, 'pesssure_avg': 0.212756536900997}],
#  [{'length': 8.668060031999627,
#    'lines': 8,
#    'pesssure_avg': 0.2613819539546963}],
#  [{'length': 4.263343462059194,
#    'lines': 9,
#    'pesssure_avg': 0.30772869288921345}],
#  [{'length': 43.35202569182504,
#    'lines': 10,
#    'pesssure_avg': 0.40624094009399414}],
#  [{'length': 68.93445946560561,
#    'lines': 11,
#    'pesssure_avg': 0.49960871253694794}],
#  [{'length': 1.9830570955063582,
#    'lines': 12,
#    'pesssure_avg': 0.40318913757801045}],
#  [{'length': 4.521881946616717,
#    'lines': 13,
#    'pesssure_avg': 0.466300457715988}],
#  [{'length': 2.582585113693709,
#    'lines': 14,
#    'pesssure_avg': 0.48424504697322845}],
#  [{'length': 11.840054884082967,
#    'lines': 15,
#    'pesssure_avg': 0.497306783994039}],
#  [{'length': 10.961135210420549,
#    'lines': 16,
#    'pesssure_avg': 0.34319065511226654}],
#  [{'length': 5.807328717420001,
#    'lines': 17,
#    'pesssure_avg': 0.40778718392054264}],
#  [{'length': 0.7540046662258054,
#    'lines': 18,
#    'pesssure_avg': 0.45860989391803697}],
#  [{'length': 1.0019623168082183,
#    'lines': 19,
#    'pesssure_avg': 0.4987716376781465}],
#  [{'length': 27.415834439256138,
#    'lines': 20,
#    'pesssure_avg': 0.5186583128842442}],
#  [{'length': 22.066992416991535,
#    'lines': 21,
#    'pesssure_avg': 0.5392298442976815}],
#  [{'length': 57.57032431956739,
#    'lines': 22,
#    'pesssure_avg': 0.5752469613438561}],
#  [{'length': 17.422212732714886,
#    'lines': 23,
#    'pesssure_avg': 0.5921975506676568}],
#  [{'length': 1.6794132661760768,
#    'lines': 24,
#    'pesssure_avg': 0.550286114215851}],
#  [{'length': 6.087851780434373,
#    'lines': 25,
#    'pesssure_avg': 0.553948283195496}],
#  [{'length': 4.21672957724447,
#    'lines': 26,
#    'pesssure_avg': 0.5532768815755849}],
#  [{'length': 3.317130719544508,
#    'lines': 27,
#    'pesssure_avg': 0.551262676715851}],
#  [{'length': 0.971038751016701,
#    'lines': 28,
#    'pesssure_avg': 0.546623945236206}],
#  [{'length': 1.1939294436382477,
#    'lines': 29,
#    'pesssure_avg': 0.5346608459949495}],
#  [{'length': 1.6762577080430083,
#    'lines': 30,
#    'pesssure_avg': 0.5768164594968157}],
#  [{'length': 0.30706941495002193,
#    'lines': 31,
#    'pesssure_avg': 0.534172594547272}],
#  [{'length': 2.6373812192300785,
#    'lines': 32,
#    'pesssure_avg': 0.521070162455241}],
#  [{'length': 6.906458754833702,
#    'lines': 33,
#    'pesssure_avg': 0.453116662800312}],
#  [{'length': 2.369014017836064,
#    'lines': 34,
#    'pesssure_avg': 0.432201623916626}]]
# [[5],
#  [{'length': 5.569485751708668,
#    'lines': 1,
#    'pesssure_avg': 0.34129855036735546}],
#  [{'length': 31.913288137096167,
#    'lines': 2,
#    'pesssure_avg': 0.735835820436478}],
#  [{'length': 8.73633357622139, 'lines': 3, 'pesssure_avg': 0.7968719005584715}],
#  [{'length': 11.150045217413233,
#    'lines': 4,
#    'pesssure_avg': 0.8124971389770506}],
#  [{'length': 99.71226998109728,
#    'lines': 5,
#    'pesssure_avg': 0.8898908959494695}],
#  [{'length': 54.918903890721204,
#    'lines': 6,
#    'pesssure_avg': 0.9458750669772807}],
#  [{'length': 32.46228173633009,
#    'lines': 7,
#    'pesssure_avg': 0.9467765263148715}],
#  [{'length': 0.49959531575385996,
#    'lines': 8,
#    'pesssure_avg': 0.946776509284973}],
#  [{'length': 4.559748177724827,
#    'lines': 9,
#    'pesssure_avg': 0.9063706398010255}],
#  [{'length': 1.0116034134204623,
#    'lines': 10,
#    'pesssure_avg': 0.90869003534317}],
#  [{'length': 0.9710387510165408,
#    'lines': 11,
#    'pesssure_avg': 0.90869003534317}],
#  [{'length': 0.919701770831858, 'lines': 12, 'pesssure_avg': 0.91064316034317}],
#  [{'length': 17.642204662815196,
#    'lines': 13,
#    'pesssure_avg': 0.9197036425272623}],
#  [{'length': 13.602022537202949,
#    'lines': 14,
#    'pesssure_avg': 0.933690392971039}],
#  [{'length': 10.02122155764706,
#    'lines': 15,
#    'pesssure_avg': 0.9439688771963118}],
#  [{'length': 5.8924956075296295,
#    'lines': 16,
#    'pesssure_avg': 0.947508990764618}],
#  [{'length': 76.87879168595322,
#    'lines': 17,
#    'pesssure_avg': 0.9483827572119865}],
#  [{'length': 10.595247795961832,
#    'lines': 18,
#    'pesssure_avg': 0.950536358356476}],
#  [{'length': 4.507271516079567,
#    'lines': 19,
#    'pesssure_avg': 0.947264830271403}],
#  [{'length': 12.119355607592972,
#    'lines': 20,
#    'pesssure_avg': 0.9467765390872955}],
#  [{'length': 32.26621034840092,
#    'lines': 21,
#    'pesssure_avg': 0.9398591071367264}],
#  [{'length': 8.175490664967025,
#    'lines': 22,
#    'pesssure_avg': 0.9364248275756839}],
#  [{'length': 6.796663223245491,
#    'lines': 23,
#    'pesssure_avg': 0.9222644448280336}],
#  [{'length': 63.84494063091124,
#    'lines': 24,
#    'pesssure_avg': 0.5923794543041901}],
#  [{'length': 47.662564220437254,
#    'lines': 25,
#    'pesssure_avg': 0.772795516711015}],
#  [{'length': 72.50347659595188,
#    'lines': 26,
#    'pesssure_avg': 0.8161018631037544}],
#  [{'length': 3.280295482200292,
#    'lines': 27,
#    'pesssure_avg': 0.8162813782691956}],
#  [{'length': 1.5308246876798397,
#    'lines': 28,
#    'pesssure_avg': 0.7853971123695376}],
#  [{'length': 5.732723832653071,
#    'lines': 29,
#    'pesssure_avg': 0.7764858305454255}],
#  [{'length': 3.639783973990067,
#    'lines': 30,
#    'pesssure_avg': 0.766597986221313}],
#  [{'length': 10.587861108844022,
#    'lines': 31,
#    'pesssure_avg': 0.766597986221313}],
#  [{'length': 8.988152919797322,
#    'lines': 32,
#    'pesssure_avg': 0.7624475359916684}],
#  [{'length': 0.7540046662255792,
#    'lines': 33,
#    'pesssure_avg': 0.7141069769859314}],
#  [{'length': 5.325460293920662,
#    'lines': 34,
#    'pesssure_avg': 0.5425955578684807}],
#  [{'length': 1.1692854960031402,
#    'lines': 35,
#    'pesssure_avg': 0.188586249947548}],
#  [{'length': 8.086615977994972,
#    'lines': 36,
#    'pesssure_avg': 0.5411551117897034}],
#  [{'length': 67.36004293857386,
#    'lines': 37,
#    'pesssure_avg': 0.6789501746495564}],
#  [{'length': 122.33653189801852,
#    'lines': 38,
#    'pesssure_avg': 0.7859098255634306}],
#  [{'length': 5.750773951111228,
#    'lines': 39,
#    'pesssure_avg': 0.784420549869537}],
#  [{'length': 1.417509934054599,
#    'lines': 40,
#    'pesssure_avg': 0.7743292450904846}],
#  [{'length': 0.651392596818053,
#    'lines': 41,
#    'pesssure_avg': 0.775631368160248}],
#  [{'length': 2.9249920310018935,
#    'lines': 42,
#    'pesssure_avg': 0.775631368160248}],
#  [{'length': 3.7847070218851706,
#    'lines': 43,
#    'pesssure_avg': 0.775631368160248}],
#  [{'length': 3.2058988115864273,
#    'lines': 44,
#    'pesssure_avg': 0.775631368160248}],
#  [{'length': 0.6004388426431974,
#    'lines': 45,
#    'pesssure_avg': 0.775631368160248}],
#  [{'length': 0.4245743773219352,
#    'lines': 46,
#    'pesssure_avg': 0.775631368160248}],
#  [{'length': 0.7323235236978104,
#    'lines': 47,
#    'pesssure_avg': 0.15721370031436266}],
#  [{'length': 0.5958021798745312,
#    'lines': 48,
#    'pesssure_avg': 0.229724571108818}],
#  [{'length': 1.9789390755227931,
#    'lines': 49,
#    'pesssure_avg': 0.28953994313875836}],
#  [{'length': 2.6464711946707027,
#    'lines': 50,
#    'pesssure_avg': 0.401520808537801}],
#  [{'length': 0.9316853611170188,
#    'lines': 51,
#    'pesssure_avg': 0.4429846704006195}],
#  [{'length': 4.155170155343764,
#    'lines': 52,
#    'pesssure_avg': 0.5206225663423537}],
#  [{'length': 2.5951263637949875,
#    'lines': 53,
#    'pesssure_avg': 0.5765926539897918}],
#  [{'length': 76.64621663640312,
#    'lines': 54,
#    'pesssure_avg': 0.7271488184152648}],
#  [{'length': 16.547294972991814,
#    'lines': 55,
#    'pesssure_avg': 0.8690979381402332}],
#  [{'length': 25.80751882412712,
#    'lines': 56,
#    'pesssure_avg': 0.8835431486368182}],
#  [{'length': 26.79689150556893,
#    'lines': 57,
#    'pesssure_avg': 0.8939367106982639}],
#  [{'length': 15.623432687470403,
#    'lines': 58,
#    'pesssure_avg': 0.897703528404236}],
#  [{'length': 11.229924868512871,
#    'lines': 59,
#    'pesssure_avg': 0.8977035284042361}],
#  [{'length': 1.7193951816831667,
#    'lines': 60,
#    'pesssure_avg': 0.897703528404236}],
#  [{'length': 1.3662119422463017,
#    'lines': 61,
#    'pesssure_avg': 0.897703528404236}],
#  [{'length': 0.48551937550854785,
#    'lines': 62,
#    'pesssure_avg': 0.897703528404236}],
#  [{'length': 0.5792816722490102,
#    'lines': 63,
#    'pesssure_avg': 0.897703528404236}],
#  [{'length': 0.5370488273929945,
#    'lines': 64,
#    'pesssure_avg': 0.8859845697879789}],
#  [{'length': 261.89301841704474,
#    'lines': 65,
#    'pesssure_avg': 0.17100785672664648}],
#  [{'length': 1.6494645623090356,
#    'lines': 66,
#    'pesssure_avg': 0.05263853818178177}],
#  [{'length': 5.562460961570499,
#    'lines': 67,
#    'pesssure_avg': 0.2613656759262086}],
#  [{'length': 5.914565578839898,
#    'lines': 68,
#    'pesssure_avg': 0.47157396674156205}],
#  [{'length': 2.051114446225428,
#    'lines': 69,
#    'pesssure_avg': 0.643549233675003}],
#  [{'length': 3.53393969781043,
#    'lines': 70,
#    'pesssure_avg': 0.7084916383028033}],
#  [{'length': 4.730745563922888,
#    'lines': 71,
#    'pesssure_avg': 0.750321706136068}],
#  [{'length': 28.65740099649607,
#    'lines': 72,
#    'pesssure_avg': 0.7912740281649998}],
#  [{'length': 25.503670175266365,
#    'lines': 73,
#    'pesssure_avg': 0.8200412154197692}],
#  [{'length': 85.36226733978526,
#    'lines': 74,
#    'pesssure_avg': 0.838736217272909}],
#  [{'length': 7.085871612579818,
#    'lines': 75,
#    'pesssure_avg': 0.8393530249595639}],
#  [{'length': 17.57108946217484,
#    'lines': 76,
#    'pesssure_avg': 0.8378881365060804}],
#  [{'length': 4.7155105800332215,
#    'lines': 77,
#    'pesssure_avg': 0.8377253711223599}],
#  [{'length': 0.15798591061400202,
#    'lines': 78,
#    'pesssure_avg': 0.839353024959564}],
#  [{'length': 6.434305796187189,
#    'lines': 79,
#    'pesssure_avg': 0.38084992766380305}],
#  [{'length': 6.005878620693607,
#    'lines': 80,
#    'pesssure_avg': 0.4453854163487754}],
#  [{'length': 12.235359413997948,
#    'lines': 81,
#    'pesssure_avg': 0.5581597685813905}],
#  [{'length': 9.30982829272006,
#    'lines': 82,
#    'pesssure_avg': 0.6126242876052858}],
#  [{'length': 4.663186982382024,
#    'lines': 83,
#    'pesssure_avg': 0.625970870256424}],
#  [{'length': 13.707524087687869,
#    'lines': 84,
#    'pesssure_avg': 0.633051037788391}],
#  [{'length': 20.560055769844766,
#    'lines': 85,
#    'pesssure_avg': 0.6631296157836912}],
#  [{'length': 21.604928666194073,
#    'lines': 86,
#    'pesssure_avg': 0.7067826390266418}],
#  [{'length': 7.089873582336126,
#    'lines': 87,
#    'pesssure_avg': 0.7284300923347476}],
#  [{'length': 1.6736235947394023,
#    'lines': 88,
#    'pesssure_avg': 0.735591650009155}],
#  [{'length': 1.6958462727281083, 'lines': 89, 'pesssure_avg': 0.7375448346138}],
#  [{'length': 6.777658988517967, 'lines': 90, 'pesssure_avg': 0.7375448346138}],
#  [{'length': 8.05296812913273,
#    'lines': 91,
#    'pesssure_avg': 0.7394979745149612}],
#  [{'length': 7.647726327626739,
#    'lines': 92,
#    'pesssure_avg': 0.742427706718445}],
#  [{'length': 15.396618576073907,
#    'lines': 93,
#    'pesssure_avg': 0.7443808615207674}],
#  [{'length': 3.167172105064096, 'lines': 94, 'pesssure_avg': 0.74535745382309}],
#  [{'length': 0.45301539690176773,
#    'lines': 95,
#    'pesssure_avg': 0.7390097081661225}],
#  [{'length': 1.605396535300692,
#    'lines': 96,
#    'pesssure_avg': 0.7197222908337912}]]
# [[6],
#  [{'length': 2.8310401226037145,
#    'lines': 1,
#    'pesssure_avg': 0.10350194200873386}],
#  [{'length': 0.9493771691949567,
#    'lines': 2,
#    'pesssure_avg': 0.497062623500824}],
#  [{'length': 1.1939294436382477,
#    'lines': 3,
#    'pesssure_avg': 0.518791496753693}],
#  [{'length': 1.4460482224958644,
#    'lines': 4,
#    'pesssure_avg': 0.6357366144657135}],
#  [{'length': 3.7989689762667282,
#    'lines': 5,
#    'pesssure_avg': 0.756832242012024}],
#  [{'length': 37.20440544310338, 'lines': 6, 'pesssure_avg': 0.367910273373127}],
#  [{'length': 0.6319436424519722,
#    'lines': 7,
#    'pesssure_avg': 0.585931181907654}],
#  [{'length': 1.2561839384441955,
#    'lines': 8,
#    'pesssure_avg': 0.5997253358364105}],
#  [{'length': 4.266919683993001,
#    'lines': 9,
#    'pesssure_avg': 0.6120546162128445}],
#  [{'length': 1.2813210365244716,
#    'lines': 10,
#    'pesssure_avg': 0.7270466089248655}],
#  [{'length': 0.8937032698124399,
#    'lines': 11,
#    'pesssure_avg': 0.7404745519161225}],
#  [{'length': 0.9667452646167934,
#    'lines': 12,
#    'pesssure_avg': 0.7578088045120235}],
#  [{'length': 1.7505650036265548,
#    'lines': 13,
#    'pesssure_avg': 0.1633173152804375}],
#  [{'length': 0.2979010899379489,
#    'lines': 14,
#    'pesssure_avg': 0.235584035515785}],
#  [{'length': 2.943893630153559,
#    'lines': 15,
#    'pesssure_avg': 0.711055159568787}],
#  [{'length': 0.40106161638372795,
#    'lines': 16,
#    'pesssure_avg': 0.11668574064970035}],
#  [{'length': 1.9492044158987638,
#    'lines': 17,
#    'pesssure_avg': 0.333974212408066}],
#  [{'length': 9.2158447857714, 'lines': 18, 'pesssure_avg': 0.775631368160248}],
#  [{'length': 1.268268189843894,
#    'lines': 19,
#    'pesssure_avg': 0.7519493401050565}],
#  [{'length': 3.2736006462096103,
#    'lines': 20,
#    'pesssure_avg': 0.22858523329099034}],
#  [{'length': 1.1692854960035703,
#    'lines': 21,
#    'pesssure_avg': 0.572503268718719}],
#  [{'length': 0.5887787260311694,
#    'lines': 22,
#    'pesssure_avg': 0.682856500148773}],
#  [{'length': 3.990901060571211,
#    'lines': 23,
#    'pesssure_avg': 0.4048574566841127}],
#  [{'length': 7.863531718385452,
#    'lines': 24,
#    'pesssure_avg': 0.6548612515131633}],
#  [{'length': 4.472548607025718,
#    'lines': 25,
#    'pesssure_avg': 0.6599069237709045}],
#  [{'length': 1.437392052931804,
#    'lines': 26,
#    'pesssure_avg': 0.6817578375339505}],
#  [{'length': 1.4228480829808594,
#    'lines': 27,
#    'pesssure_avg': 0.8375219404697415}],
#  [{'length': 2.5200829971063365,
#    'lines': 28,
#    'pesssure_avg': 0.8773174583911895}],
#  [{'length': 2.7109408386015494,
#    'lines': 29,
#    'pesssure_avg': 0.883543133735657}],
#  [{'length': 1.0996142205939778,
#    'lines': 30,
#    'pesssure_avg': 0.7045853435993195}],
#  [{'length': 5.077990381816842,
#    'lines': 31,
#    'pesssure_avg': 0.4445715993642805}],
#  [{'length': 2.0866371213322887,
#    'lines': 32,
#    'pesssure_avg': 0.6856641471385955}],
#  [{'length': 1.3006547176489336,
#    'lines': 33,
#    'pesssure_avg': 0.696162343025208}],
#  [{'length': 5.05993573406186, 'lines': 34, 'pesssure_avg': 0.580804169178009}],
#  [{'length': 5.045940169527236,
#    'lines': 35,
#    'pesssure_avg': 0.5908140540122986}],
#  [{'length': 6.797271257114959,
#    'lines': 36,
#    'pesssure_avg': 0.6998245120048525}],
#  [{'length': 5.079901504907326,
#    'lines': 37,
#    'pesssure_avg': 0.5294117629528045}],
#  [{'length': 2.8868175787468213,
#    'lines': 38,
#    'pesssure_avg': 0.593133419752121}],
#  [{'length': 2.8285900657852396,
#    'lines': 39,
#    'pesssure_avg': 0.601922631263733}],
#  [{'length': 2.1443188637496995,
#    'lines': 40,
#    'pesssure_avg': 0.760250270366669}],
#  [{'length': 8.197694567376304,
#    'lines': 41,
#    'pesssure_avg': 0.759029507637024}],
#  [{'length': 5.844129424002338,
#    'lines': 42,
#    'pesssure_avg': 0.7935352524121604}],
#  [{'length': 8.626924447769262,
#    'lines': 43,
#    'pesssure_avg': 0.673579007387161}],
#  [{'length': 5.676022360791706,
#    'lines': 44,
#    'pesssure_avg': 0.687006950378418}],
#  [{'length': 8.282674941613744,
#    'lines': 45,
#    'pesssure_avg': 0.756588101387024}],
#  [{'length': 10.847982394382647,
#    'lines': 46,
#    'pesssure_avg': 0.7702601850032805}],
#  [{'length': 6.728584301496895,
#    'lines': 47,
#    'pesssure_avg': 0.771725058555603}],
#  [{'length': 3.512991577110641,
#    'lines': 48,
#    'pesssure_avg': 0.7861295640468595}],
#  [{'length': 8.895041709220052,
#    'lines': 49,
#    'pesssure_avg': 0.7602502405643461}],
#  [{'length': 24.51932497054389,
#    'lines': 50,
#    'pesssure_avg': 0.7830370664596557}],
#  [{'length': 6.99532561086515, 'lines': 51, 'pesssure_avg': 0.633051037788391}],
#  [{'length': 12.746916642323018,
#    'lines': 52,
#    'pesssure_avg': 0.640741586685181}],
#  [{'length': 17.339362778689804,
#    'lines': 53,
#    'pesssure_avg': 0.6458279093106584}],
#  [{'length': 1.1916043597497858,
#    'lines': 54,
#    'pesssure_avg': 0.6358586847782135}],
#  [{'length': 1.4839092917061996,
#    'lines': 55,
#    'pesssure_avg': 0.643305093050003}],
#  [{'length': 8.017082340868514,
#    'lines': 56,
#    'pesssure_avg': 0.620111376047134}],
#  [{'length': 6.480846598824096,
#    'lines': 57,
#    'pesssure_avg': 0.49987028539180756}],
#  [{'length': 7.201608664858046,
#    'lines': 58,
#    'pesssure_avg': 0.632806897163391}],
#  [{'length': 16.23126557285626,
#    'lines': 59,
#    'pesssure_avg': 0.6809033354123434}],
#  [{'length': 4.7225779757385435,
#    'lines': 60,
#    'pesssure_avg': 0.6973830759525299}],
#  [{'length': 2.0565156786076373,
#    'lines': 61,
#    'pesssure_avg': 0.7365682423114776}],
#  [{'length': 9.27583464480562,
#    'lines': 62,
#    'pesssure_avg': 0.6232852637767795}],
#  [{'length': 4.8751447380359645,
#    'lines': 63,
#    'pesssure_avg': 0.726802468299866}],
#  [{'length': 5.356268638670543,
#    'lines': 64,
#    'pesssure_avg': 0.7314412295818331}],
#  [{'length': 1.2008776852875411,
#    'lines': 65,
#    'pesssure_avg': 0.735591650009155}],
#  [{'length': 4.802644645507267,
#    'lines': 66,
#    'pesssure_avg': 0.497306793928146}],
#  [{'length': 15.340550332688908,
#    'lines': 67,
#    'pesssure_avg': 0.722652018070221}],
#  [{'length': 2.866088721482718,
#    'lines': 68,
#    'pesssure_avg': 0.7602502405643465}],
#  [{'length': 3.8727141691868487,
#    'lines': 69,
#    'pesssure_avg': 0.652338445186615}],
#  [{'length': 11.690720166890655,
#    'lines': 70,
#    'pesssure_avg': 0.65575647354126}],
#  [{'length': 11.523469168285095,
#    'lines': 71,
#    'pesssure_avg': 0.6787060499191284}],
#  [{'length': 6.580218015462173,
#    'lines': 72,
#    'pesssure_avg': 0.688593864440918}],
#  [{'length': 5.217788827629224,
#    'lines': 73,
#    'pesssure_avg': 0.6994583010673525}],
#  [{'length': 1.6051105897415734,
#    'lines': 74,
#    'pesssure_avg': 0.541008621454239}],
#  [{'length': 16.780916737888933,
#    'lines': 75,
#    'pesssure_avg': 0.6852979362010955}],
#  [{'length': 2.3195191797593684,
#    'lines': 76,
#    'pesssure_avg': 0.696528553962708}],
#  [{'length': 8.395940202669237,
#    'lines': 77,
#    'pesssure_avg': 0.698481738567352}],
#  [{'length': 5.645491970244782,
#    'lines': 78,
#    'pesssure_avg': 0.7084102630615233}],
#  [{'length': 2.5825851136945044,
#    'lines': 79,
#    'pesssure_avg': 0.748287171125412}],
#  [{'length': 8.902365489842394,
#    'lines': 80,
#    'pesssure_avg': 0.807858407497406}],
#  [{'length': 6.295693936989216,
#    'lines': 81,
#    'pesssure_avg': 0.811032295227051}],
#  [{'length': 3.4633003670816227,
#    'lines': 82,
#    'pesssure_avg': 0.7401083409786225}],
#  [{'length': 19.908101150844708,
#    'lines': 83,
#    'pesssure_avg': 0.6904249588648477}],
#  [{'length': 17.1154643870286,
#    'lines': 84,
#    'pesssure_avg': 0.6223086714744566}],
#  [{'length': 2.601309435299216,
#    'lines': 85,
#    'pesssure_avg': 0.6235294342041016}],
#  [{'length': 9.60349723213312, 'lines': 86, 'pesssure_avg': 0.71125861008962}],
#  [{'length': 16.228141910790026,
#    'lines': 87,
#    'pesssure_avg': 0.7109941393136976}],
#  [{'length': 92.77517772750929,
#    'lines': 88,
#    'pesssure_avg': 0.551176509436439}],
#  [{'length': 2.2687471089539577,
#    'lines': 89,
#    'pesssure_avg': 0.64892041683197}],
#  [{'length': 14.045951550054324,
#    'lines': 90,
#    'pesssure_avg': 0.6638132333755492}],
#  [{'length': 10.151747312409553,
#    'lines': 91,
#    'pesssure_avg': 0.6713816821575165}],
#  [{'length': 9.613929495044534,
#    'lines': 92,
#    'pesssure_avg': 0.6778108477592467}],
#  [{'length': 1.7974634400368739,
#    'lines': 93,
#    'pesssure_avg': 0.684321343898773}],
#  [{'length': 3.22788237526231, 'lines': 94, 'pesssure_avg': 0.529289662837982}],
#  [{'length': 3.0160186649051592,
#    'lines': 95,
#    'pesssure_avg': 0.529289662837982}],
#  [{'length': 2.770640293665042,
#    'lines': 96,
#    'pesssure_avg': 0.535393297672272}],
#  [{'length': 2.0011548677670135,
#    'lines': 97,
#    'pesssure_avg': 0.5436942279338834}],
#  [{'length': 1.2660796322348076,
#    'lines': 98,
#    'pesssure_avg': 0.5482108891010286}]]
# [[7],
#  [{'length': 2.0484084893140677,
#    'lines': 1,
#    'pesssure_avg': 0.0754253435879944}],
#  [{'length': 1.6653177191782391,
#    'lines': 2,
#    'pesssure_avg': 0.389150843024254}],
#  [{'length': 2.6146018541691167,
#    'lines': 3,
#    'pesssure_avg': 0.626337081193924}],
#  [{'length': 3.241646876864574,
#    'lines': 4,
#    'pesssure_avg': 0.6367945869763694}],
#  [{'length': 13.832904023715086,
#    'lines': 5,
#    'pesssure_avg': 0.6611683269341787}],
#  [{'length': 28.56085462738353,
#    'lines': 6,
#    'pesssure_avg': 0.7167383035024009}],
#  [{'length': 1.508009332453072, 'lines': 7, 'pesssure_avg': 0.741451144218445}],
#  [{'length': 89.73564500022223,
#    'lines': 8,
#    'pesssure_avg': 0.7487144395709038}],
#  [{'length': 29.42109391051094,
#    'lines': 9,
#    'pesssure_avg': 0.7593085510390146}],
#  [{'length': 28.57651650025262,
#    'lines': 10,
#    'pesssure_avg': 0.7632846151079453}],
#  [{'length': 27.347917308862293,
#    'lines': 11,
#    'pesssure_avg': 0.7683070302009581}],
#  [{'length': 27.730438545242695,
#    'lines': 12,
#    'pesssure_avg': 0.7670049071311947}],
#  [{'length': 6.659668362758383,
#    'lines': 13,
#    'pesssure_avg': 0.7657028039296464}],
#  [{'length': 4.484005187009577,
#    'lines': 14,
#    'pesssure_avg': 0.764400720596313}],
#  [{'length': 5.077990381816842,
#    'lines': 15,
#    'pesssure_avg': 0.805539011955261}],
#  [{'length': 2.1384910197333133,
#    'lines': 16,
#    'pesssure_avg': 0.817013800144196}],
#  [{'length': 9.092238233850976,
#    'lines': 17,
#    'pesssure_avg': 0.8317845463752744}],
#  [{'length': 96.25724230046265,
#    'lines': 18,
#    'pesssure_avg': 0.8684265365203222}],
#  [{'length': 15.567672099419848,
#    'lines': 19,
#    'pesssure_avg': 0.9025864005088807}],
#  [{'length': 69.33969128157123,
#    'lines': 20,
#    'pesssure_avg': 0.9051255106925964}],
#  [{'length': 41.182911798769275,
#    'lines': 21,
#    'pesssure_avg': 0.8829676636627742}],
#  [{'length': 9.093211588599644,
#    'lines': 22,
#    'pesssure_avg': 0.8652323335409167}],
#  [{'length': 10.427758917208484,
#    'lines': 23,
#    'pesssure_avg': 0.8605325371026992}],
#  [{'length': 8.547222315552947,
#    'lines': 24,
#    'pesssure_avg': 0.856931388378143}],
#  [{'length': 5.336784148478087,
#    'lines': 25,
#    'pesssure_avg': 0.855466544628143}],
#  [{'length': 1.7694735450012076,
#    'lines': 26,
#    'pesssure_avg': 0.8502174317836765}],
#  [{'length': 0.5598044220586245,
#    'lines': 27,
#    'pesssure_avg': 0.6977492868900299}],
#  [{'length': 2.067546044011088,
#    'lines': 28,
#    'pesssure_avg': 0.546949466069539}],
#  [{'length': 0.21064788081696406,
#    'lines': 29,
#    'pesssure_avg': 0.2468146830797195}],
#  [{'length': 1.2682681898439316,
#    'lines': 30,
#    'pesssure_avg': 0.5773861408233645}],
#  [{'length': 7.956583259112893,
#    'lines': 31,
#    'pesssure_avg': 0.6746532440185548}],
#  [{'length': 3.3181220487002396,
#    'lines': 32,
#    'pesssure_avg': 0.7189898788928984}],
#  [{'length': 1.0598017068554104,
#    'lines': 33,
#    'pesssure_avg': 0.733638525009155}],
#  [{'length': 1.2327851158996208,
#    'lines': 34,
#    'pesssure_avg': 0.74731057882309}],
#  [{'length': 5.21616332436352,
#    'lines': 35,
#    'pesssure_avg': 0.7518679499626156}],
#  [{'length': 4.632457735669217,
#    'lines': 36,
#    'pesssure_avg': 0.765865564346313}],
#  [{'length': 7.910171517312643,
#    'lines': 37,
#    'pesssure_avg': 0.767818748950958}],
#  [{'length': 8.779897195821052,
#    'lines': 38,
#    'pesssure_avg': 0.795162916183472}],
#  [{'length': 2.6878248623443612,
#    'lines': 39,
#    'pesssure_avg': 0.795162916183472}],
#  [{'length': 2.795056083349392,
#    'lines': 40,
#    'pesssure_avg': 0.797116041183472}],
#  [{'length': 3.3306354383575205,
#    'lines': 41,
#    'pesssure_avg': 0.799069225788116}],
#  [{'length': 5.009811584040016,
#    'lines': 42,
#    'pesssure_avg': 0.797116041183472}],
#  [{'length': 4.291546703193431,
#    'lines': 43,
#    'pesssure_avg': 0.797116041183472}],
#  [{'length': 7.091615214672198,
#    'lines': 44,
#    'pesssure_avg': 0.797116041183472}],
#  [{'length': 4.983169365918599,
#    'lines': 45,
#    'pesssure_avg': 0.797116041183472}],
#  [{'length': 3.775903659652037,
#    'lines': 46,
#    'pesssure_avg': 0.799069225788116}],
#  [{'length': 2.620958270001797,
#    'lines': 47,
#    'pesssure_avg': 0.8062714636325835}],
#  [{'length': 2.1992284411882497,
#    'lines': 48,
#    'pesssure_avg': 0.8529030382633209}],
#  [{'length': 2.517330311416531,
#    'lines': 49,
#    'pesssure_avg': 0.863035023212433}],
#  [{'length': 2.2650769845083176,
#    'lines': 50,
#    'pesssure_avg': 0.874265640974045}],
#  [{'length': 4.4138774131502565,
#    'lines': 51,
#    'pesssure_avg': 0.9128404855728149}],
#  [{'length': 0.3203302591306693,
#    'lines': 52,
#    'pesssure_avg': 0.928954005241394}],
#  [{'length': 0.2685244136965697,
#    'lines': 53,
#    'pesssure_avg': 0.25377278774976697}],
#  [{'length': 0.3372011378065012,
#    'lines': 54,
#    'pesssure_avg': 0.447745472192764}],
#  [{'length': 2.0232068268415637,
#    'lines': 55,
#    'pesssure_avg': 0.873533219099045}],
#  [{'length': 4.0267055388104165,
#    'lines': 56,
#    'pesssure_avg': 0.905711472034454}],
#  [{'length': 1.066323625070166, 'lines': 57, 'pesssure_avg': 0.90942245721817}],
#  [{'length': 1.4669927368976616,
#    'lines': 58,
#    'pesssure_avg': 0.9154039919376376}],
#  [{'length': 2.4907497481074428,
#    'lines': 59,
#    'pesssure_avg': 0.91845577955246}],
#  [{'length': 1.583366011903652,
#    'lines': 60,
#    'pesssure_avg': 0.9194323718547821}],
#  [{'length': 2.423835512327188,
#    'lines': 61,
#    'pesssure_avg': 0.920408964157104}],
#  [{'length': 2.8412941005901438,
#    'lines': 62,
#    'pesssure_avg': 0.920408964157104}],
#  [{'length': 21.646307064017275,
#    'lines': 63,
#    'pesssure_avg': 0.9175543418297399}],
#  [{'length': 6.8811998948542605,
#    'lines': 64,
#    'pesssure_avg': 0.8842348953088123}],
#  [{'length': 2.1922818300508133,
#    'lines': 65,
#    'pesssure_avg': 0.729488044977188}],
#  [{'length': 5.463155936337077,
#    'lines': 66,
#    'pesssure_avg': 0.6905470192432399}],
#  [{'length': 4.70197968089151, 'lines': 67, 'pesssure_avg': 0.712153822183609}],
#  [{'length': 7.9115737813743054,
#    'lines': 68,
#    'pesssure_avg': 0.7614709734916685}],
#  [{'length': 3.0909481230704547,
#    'lines': 69,
#    'pesssure_avg': 0.82738995552063}],
#  [{'length': 2.107794946266812, 'lines': 70, 'pesssure_avg': 0.82738995552063}],
#  [{'length': 0.9420459616492651,
#    'lines': 71,
#    'pesssure_avg': 0.82738995552063}],
#  [{'length': 2.543633127213275,
#    'lines': 72,
#    'pesssure_avg': 0.824460208415985}],
#  [{'length': 4.539938330239576,
#    'lines': 73,
#    'pesssure_avg': 0.8214084208011625}],
#  [{'length': 17.484243091148954,
#    'lines': 74,
#    'pesssure_avg': 0.8169893980026248}],
#  [{'length': 5.000503014393435,
#    'lines': 75,
#    'pesssure_avg': 0.815426886081696}],
#  [{'length': 5.493024685108768,
#    'lines': 76,
#    'pesssure_avg': 0.815426886081696}],
#  [{'length': 5.176165384261959,
#    'lines': 77,
#    'pesssure_avg': 0.8173800408840179}],
#  [{'length': 4.06828631926038,
#    'lines': 78,
#    'pesssure_avg': 0.8260878324508667}],
#  [{'length': 2.0184035479637927,
#    'lines': 79,
#    'pesssure_avg': 0.833493530750275}],
#  [{'length': 1.4829745456034833,
#    'lines': 80,
#    'pesssure_avg': 0.8315403759479525}],
#  [{'length': 0.48551937550801144,
#    'lines': 81,
#    'pesssure_avg': 0.176501102745533}],
#  [{'length': 0.33720113780634137,
#    'lines': 82,
#    'pesssure_avg': 0.5085374116897585}],
#  [{'length': 9.287141916413752,
#    'lines': 83,
#    'pesssure_avg': 0.6546171307563781}],
#  [{'length': 3.985992839078916,
#    'lines': 84,
#    'pesssure_avg': 0.723384439945221}],
#  [{'length': 12.495824321624147,
#    'lines': 85,
#    'pesssure_avg': 0.750948339700699}],
#  [{'length': 17.830535928122636,
#    'lines': 86,
#    'pesssure_avg': 0.7525461316108703}],
#  [{'length': 0.8021232327682472,
#    'lines': 87,
#    'pesssure_avg': 0.749019622802734}],
#  [{'length': 4.269040621995831,
#    'lines': 88,
#    'pesssure_avg': 0.7457643548647567}],
#  [{'length': 6.016102081752729,
#    'lines': 89,
#    'pesssure_avg': 0.7202105671167375}],
#  [{'length': 1.26498393351568,
#    'lines': 90,
#    'pesssure_avg': 0.6512397825717925}],
#  [{'length': 2.690403112204594,
#    'lines': 91,
#    'pesssure_avg': 0.878171980381012}],
#  [{'length': 0.5186602561056294,
#    'lines': 92,
#    'pesssure_avg': 0.8779278099536895}],
#  [{'length': 0.23551149041183328,
#    'lines': 93,
#    'pesssure_avg': 0.870603501796722}],
#  [{'length': 0.8968225112299734,
#    'lines': 94,
#    'pesssure_avg': 0.843259334564209}],
#  [{'length': 0.40106161638464605,
#    'lines': 95,
#    'pesssure_avg': 0.843259334564209}],
#  [{'length': 0.372376362422002,
#    'lines': 96,
#    'pesssure_avg': 0.843259334564209}],
#  [{'length': 0.30706941495011947,
#    'lines': 97,
#    'pesssure_avg': 0.845212459564209}],
#  [{'length': 4.496357841781972,
#    'lines': 98,
#    'pesssure_avg': 0.8653950691223146}],
#  [{'length': 1.5162624095848867,
#    'lines': 99,
#    'pesssure_avg': 0.871824204921722}],
#  [{'length': 1.2561839384441955,
#    'lines': 100,
#    'pesssure_avg': 0.873044908046722}],
#  [{'length': 4.771360499438526,
#    'lines': 101,
#    'pesssure_avg': 0.873044908046722}],
#  [{'length': 3.798238896702739,
#    'lines': 102,
#    'pesssure_avg': 0.873044908046722}],
#  [{'length': 4.9831693659186, 'lines': 103, 'pesssure_avg': 0.873044908046722}],
#  [{'length': 14.443885239848756,
#    'lines': 104,
#    'pesssure_avg': 0.87421680688858}],
#  [{'length': 3.7964130835428764,
#    'lines': 105,
#    'pesssure_avg': 0.882200360298157}],
#  [{'length': 3.433544663677392,
#    'lines': 106,
#    'pesssure_avg': 0.880369285742442}],
#  [{'length': 3.298001870979907,
#    'lines': 107,
#    'pesssure_avg': 0.878904402256012}],
#  [{'length': 19.334612057593578,
#    'lines': 108,
#    'pesssure_avg': 0.8779278099536896}],
#  [{'length': 11.735820507961375,
#    'lines': 109,
#    'pesssure_avg': 0.8769512176513669}],
#  [{'length': 0.9197017708324504,
#    'lines': 110,
#    'pesssure_avg': 0.880857527256012}],
#  [{'length': 0.9493771691946697,
#    'lines': 111,
#    'pesssure_avg': 0.122301060706377}],
#  [{'length': 0.666127087671382,
#    'lines': 112,
#    'pesssure_avg': 0.36437018215656247}],
#  [{'length': 1.6653317721838277,
#    'lines': 113,
#    'pesssure_avg': 0.4852623144785566}],
#  [{'length': 0.5671867772389063,
#    'lines': 114,
#    'pesssure_avg': 0.7047073841094975}],
#  [{'length': 0.8968010374018317,
#    'lines': 115,
#    'pesssure_avg': 0.7224078476428984}],
#  [{'length': 2.8036728781871987,
#    'lines': 116,
#    'pesssure_avg': 0.7659876346588135}],
#  [{'length': 0.6598525953660701,
#    'lines': 117,
#    'pesssure_avg': 0.7873502671718595}],
#  [{'length': 0.36863379143107977,
#    'lines': 118,
#    'pesssure_avg': 0.7896289428075153}],
#  [{'length': 0.2171308656051537,
#    'lines': 119,
#    'pesssure_avg': 0.790279984474182}],
#  [{'length': 0.30706941495011947,
#    'lines': 120,
#    'pesssure_avg': 0.790279984474182}],
#  [{'length': 0.3070694149496515,
#    'lines': 121,
#    'pesssure_avg': 0.799069225788116}],
#  [{'length': 0.2979010899373058,
#    'lines': 122,
#    'pesssure_avg': 0.801022350788116}],
#  [{'length': 0.6341340949226834,
#    'lines': 123,
#    'pesssure_avg': 0.802975535392761}],
#  [{'length': 0.5598044220585817,
#    'lines': 124,
#    'pesssure_avg': 0.802975535392761}],
#  [{'length': 1.0663236250702277,
#    'lines': 125,
#    'pesssure_avg': 0.8059052526950835}],
#  [{'length': 0.9795692699392984,
#    'lines': 126,
#    'pesssure_avg': 0.807858407497406}],
#  [{'length': 3.344581364528106,
#    'lines': 127,
#    'pesssure_avg': 0.812741279602051}],
#  [{'length': 0.8572747651943604,
#    'lines': 128,
#    'pesssure_avg': 0.812741279602051}],
#  [{'length': 0.9212082448494224,
#    'lines': 129,
#    'pesssure_avg': 0.812741279602051}],
#  [{'length': 0.35326723561782614,
#    'lines': 130,
#    'pesssure_avg': 0.808834969997406}],
#  [{'length': 1.285642536268498,
#    'lines': 131,
#    'pesssure_avg': 0.8077363073825835}],
#  [{'length': 0.5598044220586565,
#    'lines': 132,
#    'pesssure_avg': 0.806637644767761}],
#  [{'length': 1.2269798106089678,
#    'lines': 133,
#    'pesssure_avg': 0.799435406923294}]]
# [[8],
#  [{'length': 1.475475258370131,
#    'lines': 1,
#    'pesssure_avg': 0.6429389119148254}],
#  [{'length': 4.363640888580078, 'lines': 2, 'pesssure_avg': 0.695796132087708}],
#  [{'length': 4.267894497168447, 'lines': 3, 'pesssure_avg': 0.696772694587708}],
#  [{'length': 3.706594731850073, 'lines': 4, 'pesssure_avg': 0.714106976985931}],
#  [{'length': 0.23551149041173158,
#    'lines': 5,
#    'pesssure_avg': 0.719722270965576}],
#  [{'length': 3.4031206634303137,
#    'lines': 6,
#    'pesssure_avg': 0.7221637070178984}],
#  [{'length': 9.610912908174782, 'lines': 7, 'pesssure_avg': 0.7391317486763}],
#  [{'length': 8.062770805429052, 'lines': 8, 'pesssure_avg': 0.803138275941213}],
#  [{'length': 11.123328732337818,
#    'lines': 9,
#    'pesssure_avg': 0.8652323186397549}],
#  [{'length': 6.0066205389262, 'lines': 10, 'pesssure_avg': 0.9205716848373413}],
#  [{'length': 15.994326392633496,
#    'lines': 11,
#    'pesssure_avg': 0.9431957403818764}],
#  [{'length': 11.337736383770967,
#    'lines': 12,
#    'pesssure_avg': 0.950926979382833}],
#  [{'length': 1.3038508995019076,
#    'lines': 13,
#    'pesssure_avg': 0.9661249667406082}],
#  [{'length': 11.472194848088249,
#    'lines': 14,
#    'pesssure_avg': 0.9635411302248637}],
#  [{'length': 49.9824439022741,
#    'lines': 15,
#    'pesssure_avg': 0.9642661538991061}],
#  [{'length': 30.48707173691487,
#    'lines': 16,
#    'pesssure_avg': 0.9664804269285763}],
#  [{'length': 8.418555949538305,
#    'lines': 17,
#    'pesssure_avg': 0.965331494808197}],
#  [{'length': 0.4739577318390502,
#    'lines': 18,
#    'pesssure_avg': 0.9599603414535525}],
#  [{'length': 1.3165492551104216,
#    'lines': 19,
#    'pesssure_avg': 0.45360495150089253}],
#  [{'length': 1.134373554476356,
#    'lines': 20,
#    'pesssure_avg': 0.1658808290958405}],
#  [{'length': 4.243384368609154,
#    'lines': 21,
#    'pesssure_avg': 0.36636403203010565}],
#  [{'length': 42.88876624316877,
#    'lines': 22,
#    'pesssure_avg': 0.690902634807255}],
#  [{'length': 7.384369538052164,
#    'lines': 23,
#    'pesssure_avg': 0.724849343299866}],
# ...
#    'lines': 21,
#    'pesssure_avg': 0.8691386312246323}],
#  [{'length': 40.28403960380488,
#    'lines': 22,
#    'pesssure_avg': 0.8834943175315858}],
#  [{'length': 6.330417148416348,
#    'lines': 23,
#    'pesssure_avg': 0.8855776786804203}],
#  [{'length': 16.05562390831081,
#    'lines': 24,
#    'pesssure_avg': 0.8895491003990175}],
#  [{'length': 0.7899295530659174,
#    'lines': 25,
#    'pesssure_avg': 0.893308937549591}],
#  [{'length': 0.44994407066320063,
#    'lines': 26,
#    'pesssure_avg': 0.893308937549591}],
#  [{'length': 2.26721940585393, 'lines': 27, 'pesssure_avg': 0.893308937549591}],
#  [{'length': 2.234878715627072,
#    'lines': 28,
#    'pesssure_avg': 0.893308937549591}],
#  [{'length': 2.416145885026355,
#    'lines': 29,
#    'pesssure_avg': 0.893308937549591}],
#  [{'length': 1.530824687679695,
#    'lines': 30,
#    'pesssure_avg': 0.897215247154236}],
#  [{'length': 0.8968010374018317,
#    'lines': 31,
#    'pesssure_avg': 0.9084458649158476}]]
# [[19],
#  [{'length': 1.464154309077873,
#    'lines': 1,
#    'pesssure_avg': 0.0751812011003494}],
#  [{'length': 1.9830970498879088,
#    'lines': 2,
#    'pesssure_avg': 0.522290905316671}],
#  [{'length': 3.730460377078838, 'lines': 3, 'pesssure_avg': 0.624017685651779}],
#  [{'length': 0.8038500877990796,
#    'lines': 4,
#    'pesssure_avg': 0.2836804687976835}],
#  [{'length': 3.8470465064361936,
#    'lines': 5,
#    'pesssure_avg': 0.43114366134007803}],
#  [{'length': 1.622296417863494, 'lines': 6, 'pesssure_avg': 0.498039230704308}],
#  [{'length': 1.750565003626546, 'lines': 7, 'pesssure_avg': 0.534416735172272}],
#  [{'length': 1.110905478465863, 'lines': 8, 'pesssure_avg': 0.743404269218445}],
#  [{'length': 4.010677046495088,
#    'lines': 9,
#    'pesssure_avg': 0.6799267530441285}],
#  [{'length': 0.9894285908299153,
#    'lines': 10,
#    'pesssure_avg': 0.652338445186615}],
#  [{'length': 0.8038500877986849,
#    'lines': 11,
#    'pesssure_avg': 0.6373235881328585}],
#  [{'length': 0.8491487546429539,
#    'lines': 12,
#    'pesssure_avg': 0.6165712773799895}],
#  [{'length': 1.2020318207631597,
#    'lines': 13,
#    'pesssure_avg': 0.7504844665527346}],
#  [{'length': 10.50438222119956,
#    'lines': 14,
#    'pesssure_avg': 0.773922344048818}],
#  [{'length': 5.415897035383976,
#    'lines': 15,
#    'pesssure_avg': 0.7560184200604754}],
#  [{'length': 3.404007372571198,
#    'lines': 16,
#    'pesssure_avg': 0.7493451237678528}],
#  [{'length': 3.135488575980012,
#    'lines': 17,
#    'pesssure_avg': 0.747188538312912}],
#  [{'length': 3.612626509335083,
#    'lines': 18,
#    'pesssure_avg': 0.7617151141166685}],
#  [{'length': 4.1022288924504124,
#    'lines': 19,
#    'pesssure_avg': 0.8188449144363406}],
#  [{'length': 7.184254814722077,
#    'lines': 20,
#    'pesssure_avg': 0.7836067279179889}],
#  [{'length': 9.002589595194031,
#    'lines': 21,
#    'pesssure_avg': 0.7883268396059671}],
#  [{'length': 0.33720113780706934,
#    'lines': 22,
#    'pesssure_avg': 0.788937211036682}],
#  [{'length': 1.1692854960036934,
#    'lines': 23,
#    'pesssure_avg': 0.642572671175003}],
#  [{'length': 4.500186147549436,
#    'lines': 24,
#    'pesssure_avg': 0.7277790506680807}],
#  [{'length': 2.7109408386014113,
#    'lines': 25,
#    'pesssure_avg': 0.7639124095439911}],
#  [{'length': 4.940412087169191,
#    'lines': 26,
#    'pesssure_avg': 0.7481244206428528}],
#  [{'length': 2.104503057726386,
#    'lines': 27,
#    'pesssure_avg': 0.7651331126689911}],
#  [{'length': 0.3723763624217126,
#    'lines': 28,
#    'pesssure_avg': 0.790524125099182}],
#  [{'length': 3.0976700189179263,
#    'lines': 29,
#    'pesssure_avg': 0.792477309703827}],
#  [{'length': 0.5887787260314389,
#    'lines': 30,
#    'pesssure_avg': 0.7665979862213135}],
#  [{'length': 0.6868202826272378,
#    'lines': 31,
#    'pesssure_avg': 0.7093868255615233}],
#  [{'length': 7.414719191703266,
#    'lines': 32,
#    'pesssure_avg': 0.7745937258005143}],
#  [{'length': 3.7989689762667425,
#    'lines': 33,
#    'pesssure_avg': 0.7935759425163265}],
#  [{'length': 1.2682681898438561,
#    'lines': 34,
#    'pesssure_avg': 0.814938604831696}],
#  [{'length': 6.78171854578006,
#    'lines': 35,
#    'pesssure_avg': 0.7916634877522787}],
#  [{'length': 5.940696450642972,
#    'lines': 36,
#    'pesssure_avg': 0.7667607863744097}],
#  [{'length': 0.9795692699393901,
#    'lines': 37,
#    'pesssure_avg': 0.759761929512024}],
#  [{'length': 2.8983227093446464,
#    'lines': 38,
#    'pesssure_avg': 0.755123198032379}],
#  [{'length': 0.7334963684491125,
#    'lines': 39,
#    'pesssure_avg': 0.755123198032379}],
#  [{'length': 5.395267216398581, 'lines': 40, 'pesssure_avg': 0.80340276658535}],
#  [{'length': 4.113031357215974,
#    'lines': 41,
#    'pesssure_avg': 0.825192630290985}],
#  [{'length': 1.0373205122117781,
#    'lines': 42,
#    'pesssure_avg': 0.847898066043854}],
#  [{'length': 0.7828764694282215,
#    'lines': 43,
#    'pesssure_avg': 0.8024872243404385}],
#  [{'length': 0.8637205308791815,
#    'lines': 44,
#    'pesssure_avg': 0.789791703224182}],
#  [{'length': 0.9212082448491691,
#    'lines': 45,
#    'pesssure_avg': 0.792233169078827}],
#  [{'length': 0.5498071102970433,
#    'lines': 46,
#    'pesssure_avg': 0.791500747203827}],
#  [{'length': 1.6333702421037668,
#    'lines': 47,
#    'pesssure_avg': 0.675532162189484}],
#  [{'length': 2.2004891053455373,
#    'lines': 48,
#    'pesssure_avg': 0.5736018717288971}],
#  [{'length': 1.2737231319636342,
#    'lines': 49,
#    'pesssure_avg': 0.642084389925003}],
#  [{'length': 1.0856543280287465,
#    'lines': 50,
#    'pesssure_avg': 0.789791703224182}],
#  [{'length': 1.359046190704398,
#    'lines': 51,
#    'pesssure_avg': 0.789791703224182}],
#  [{'length': 6.8914783020046215,
#    'lines': 52,
#    'pesssure_avg': 0.7877164781093595}],
#  [{'length': 1.3853201468329575,
#    'lines': 53,
#    'pesssure_avg': 0.773434042930603}],
#  [{'length': 3.345589726050199,
#    'lines': 54,
#    'pesssure_avg': 0.8011444211006165}],
#  [{'length': 5.144485749599845,
#    'lines': 55,
#    'pesssure_avg': 0.6383001506328582}],
#  [{'length': 2.4298806004146694,
#    'lines': 56,
#    'pesssure_avg': 0.551873058080673}],
#  [{'length': 0.44685163490551655,
#    'lines': 57,
#    'pesssure_avg': 0.438101768493652}],
#  [{'length': 0.49681203328590895,
#    'lines': 58,
#    'pesssure_avg': 0.324208438396454}],
#  [{'length': 0.9376197227774589,
#    'lines': 59,
#    'pesssure_avg': 0.350576028227806}],
#  [{'length': 2.6471007285077084,
#    'lines': 60,
#    'pesssure_avg': 0.3970448374748234}],
#  [{'length': 0.6363170070394172,
#    'lines': 61,
#    'pesssure_avg': 0.5028000175952915}],
#  [{'length': 3.322316946408584,
#    'lines': 62,
#    'pesssure_avg': 0.5210701624552406}]]
# [[20],
#  [{'length': 4.380766952510581,
#    'lines': 1,
#    'pesssure_avg': 0.6038757860660551}],
#  [{'length': 12.297864763516332,
#    'lines': 2,
#    'pesssure_avg': 0.7218381961186727}],
#  [{'length': 0.8685234624239512,
#    'lines': 3,
#    'pesssure_avg': 0.7165484130382535}],
#  [{'length': 0.5887787260305237,
#    'lines': 4,
#    'pesssure_avg': 0.6901808083057405}],
#  [{'length': 1.7537267466003723,
#    'lines': 5,
#    'pesssure_avg': 0.688960075378418}],
#  [{'length': 16.819868968883874,
#    'lines': 6,
#    'pesssure_avg': 0.7028937637805939}],
#  [{'length': 6.8498786395619025,
#    'lines': 7,
#    'pesssure_avg': 0.7321736514568333}],
#  [{'length': 5.08971880278025, 'lines': 8, 'pesssure_avg': 0.747310608625412}],
#  [{'length': 3.723763624218753,
#    'lines': 9,
#    'pesssure_avg': 0.7521934807300565}],
#  [{'length': 13.718423184677526,
#    'lines': 10,
#    'pesssure_avg': 0.754146635532379}],
#  [{'length': 77.6137874270457,
#    'lines': 11,
#    'pesssure_avg': 0.7525771402177356}],
#  [{'length': 4.988453598905493,
#    'lines': 12,
#    'pesssure_avg': 0.747798889875412}],
#  [{'length': 9.802811100865608,
#    'lines': 13,
#    'pesssure_avg': 0.7288370033105215}],
#  [{'length': 22.249373368759244,
#    'lines': 14,
#    'pesssure_avg': 0.770699620246887}],
#  [{'length': 3.73157533412825, 'lines': 15, 'pesssure_avg': 0.913328766822815}],
#  [{'length': 3.7424024505682256,
#    'lines': 16,
#    'pesssure_avg': 0.9077134281396863}],
#  [{'length': 15.90401823385138,
#    'lines': 17,
#    'pesssure_avg': 0.9202587008476257}],
#  [{'length': 77.55952333364505,
#    'lines': 18,
#    'pesssure_avg': 0.9629431392835535}],
#  [{'length': 27.255256485871335,
#    'lines': 19,
#    'pesssure_avg': 0.969237804412842}],
#  [{'length': 18.381460639256602,
#    'lines': 20,
#    'pesssure_avg': 0.9692378044128419}],
#  [{'length': 1.8701869675345755,
#    'lines': 21,
#    'pesssure_avg': 0.9666335980097452}],
#  [{'length': 0.9533666102434475,
#    'lines': 22,
#    'pesssure_avg': 0.9173815488815308}],
#  [{'length': 0.32033025913151036,
#    'lines': 23,
#    'pesssure_avg': 0.81933319568634}],
#  [{'length': 0.26330985102208615,
#    'lines': 24,
#    'pesssure_avg': 0.8050507307052615}],
#  [{'length': 2.6446587668077806,
#    'lines': 25,
#    'pesssure_avg': 0.676630824804306}],
#  [{'length': 3.0670794405928725,
#    'lines': 26,
#    'pesssure_avg': 0.809567421674728}],
#  [{'length': 6.97914794439421,
#    'lines': 27,
#    'pesssure_avg': 0.8457007706165313}],
#  [{'length': 4.213410920986886,
#    'lines': 28,
#    'pesssure_avg': 0.8749980926513673}],
#  [{'length': 6.268781607637413,
#    'lines': 29,
#    'pesssure_avg': 0.8937971989313763}],
#  [{'length': 4.972863560119329,
#    'lines': 30,
#    'pesssure_avg': 0.9030747016270957}],
#  [{'length': 1.9598461933394002,
#    'lines': 31,
#    'pesssure_avg': 0.9113756120204926}],
#  [{'length': 0.41130313572136734,
#    'lines': 32,
#    'pesssure_avg': 0.914305329322815}],
#  [{'length': 1.0663236250702277,
#    'lines': 33,
#    'pesssure_avg': 0.91625851392746}],
#  [{'length': 0.7484672253168877,
#    'lines': 34,
#    'pesssure_avg': 0.9277332723140715}],
#  [{'length': 1.6017234326584917,
#    'lines': 35,
#    'pesssure_avg': 0.9374176661173507}],
#  [{'length': 1.584241525386891,
#    'lines': 36,
#    'pesssure_avg': 0.945067524909973}],
#  [{'length': 2.0726349246550932,
#    'lines': 37,
#    'pesssure_avg': 0.9594720304012295}],
#  [{'length': 41.884741759060276,
#    'lines': 38,
#    'pesssure_avg': 0.9945241894040789}],
#  [{'length': 2.4435381165052843, 'lines': 39, 'pesssure_avg': 1.0}],
#  [{'length': 2.059884256915053, 'lines': 40, 'pesssure_avg': 1.0}],
#  [{'length': 1.6736235947397242, 'lines': 41, 'pesssure_avg': 1.0}],
#  [{'length': 1.134373554477264, 'lines': 42, 'pesssure_avg': 1.0}],
#  [{'length': 0.8491487546415579, 'lines': 43, 'pesssure_avg': 1.0}],
#  [{'length': 0.23551149041173158, 'lines': 44, 'pesssure_avg': 1.0}],
#  [{'length': 1.7702570179399764, 'lines': 45, 'pesssure_avg': 1.0}],
#  [{'length': 3.39049278452158, 'lines': 46, 'pesssure_avg': 1.0}],
#  [{'length': 18.143138884272517, 'lines': 47, 'pesssure_avg': 1.0}],
#  [{'length': 14.136474735815707, 'lines': 48, 'pesssure_avg': 1.0}],
#  [{'length': 8.163439787901172, 'lines': 49, 'pesssure_avg': 1.0}],
#  [{'length': 12.822443760459949, 'lines': 50, 'pesssure_avg': 1.0}],
#  [{'length': 1.9426211172098298, 'lines': 51, 'pesssure_avg': 1.0}],
#  [{'length': 0.9420459616492651, 'lines': 52, 'pesssure_avg': 1.0}],
#  [{'length': 0.41130313572116356, 'lines': 53, 'pesssure_avg': 1.0}],
#  [{'length': 1.36030881903809,
#    'lines': 54,
#    'pesssure_avg': 0.9479972521464027}],
#  [{'length': 1.3661696564517367,
#    'lines': 55,
#    'pesssure_avg': 0.937010765075684}],
#  [{'length': 0.6141388299004533,
#    'lines': 56,
#    'pesssure_avg': 0.933836877346039}],
#  [{'length': 1.1392526030342962,
#    'lines': 57,
#    'pesssure_avg': 0.914915680885315}],
#  [{'length': 0.8952534934747104,
#    'lines': 58,
#    'pesssure_avg': 0.901853978633881}],
#  [{'length': 0.307069414949593,
#    'lines': 59,
#    'pesssure_avg': 0.895994484424591}]]
# [[21],
#  [{'length': 2.3208692599849057,
#    'lines': 1,
#    'pesssure_avg': 0.44937310616175336}],
#  [{'length': 47.8945591229544, 'lines': 2, 'pesssure_avg': 0.6763256217042605}],
#  [{'length': 4.7506425765637985,
#    'lines': 3,
#    'pesssure_avg': 0.7965463797251386}],
#  [{'length': 2.7565913208014914,
#    'lines': 4,
#    'pesssure_avg': 0.797848463058472}],
#  [{'length': 0.7065344712362116,
#    'lines': 5,
#    'pesssure_avg': 0.7922331392765045}],
#  [{'length': 1.4669927368973352,
#    'lines': 6,
#    'pesssure_avg': 0.1827267855405805}],
#  [{'length': 1.8181731111545616,
#    'lines': 7,
#    'pesssure_avg': 0.350576028227806}],
#  [{'length': 57.41992954941067,
#    'lines': 8,
#    'pesssure_avg': 0.6191922548939202}],
#  [{'length': 2.0692871031755327,
#    'lines': 9,
#    'pesssure_avg': 0.18980697542428998}],
#  [{'length': 7.115619169515596,
#    'lines': 10,
#    'pesssure_avg': 0.42088959614435834}],
#  [{'length': 3.9618769004675887,
#    'lines': 11,
#    'pesssure_avg': 0.672175168991089}],
#  [{'length': 12.285768493568037,
#    'lines': 12,
#    'pesssure_avg': 0.7756313482920328}],
#  [{'length': 13.58029505861839,
#    'lines': 13,
#    'pesssure_avg': 0.8130900519234794}],
#  [{'length': 4.795736441500619,
#    'lines': 14,
#    'pesssure_avg': 0.8281712055206301}],
#  [{'length': 1.4386963395663759,
#    'lines': 15,
#    'pesssure_avg': 0.8224256634712219}],
#  [{'length': 0.2685244136966812,
#    'lines': 16,
#    'pesssure_avg': 0.809079110622406}],
#  [{'length': 2.478274370059262,
#    'lines': 17,
#    'pesssure_avg': 0.6335393190383913}],
#  [{'length': 7.934702467127736,
#    'lines': 18,
#    'pesssure_avg': 0.7337849974632261}],
#  [{'length': 11.497788411893348,
#    'lines': 19,
#    'pesssure_avg': 0.7962004840373993}],
#  [{'length': 25.05006732647792,
#    'lines': 20,
#    'pesssure_avg': 0.8703322211901346}],
#  [{'length': 8.763194555885566,
#    'lines': 21,
#    'pesssure_avg': 0.9095201015472414}],
#  [{'length': 41.752946163009355,
#    'lines': 22,
#    'pesssure_avg': 0.9209100917765967}],
#  [{'length': 0.48551937550802376,
#    'lines': 23,
#    'pesssure_avg': 0.637811839580536}],
#  [{'length': 2.9083523639210527,
#    'lines': 24,
#    'pesssure_avg': 0.4648355841636655}],
#  [{'length': 1.0386564052468021,
#    'lines': 25,
#    'pesssure_avg': 0.5285572707653046}],
#  [{'length': 4.380261280098994,
#    'lines': 26,
#    'pesssure_avg': 0.7430991083383558}],
#  [{'length': 19.88913868704452,
#    'lines': 27,
#    'pesssure_avg': 0.793542661450126}],
#  [{'length': 13.191101595473954,
#    'lines': 28,
#    'pesssure_avg': 0.8247314691543578}],
#  [{'length': 3.611539865623061,
#    'lines': 29,
#    'pesssure_avg': 0.809506356716156}],
#  [{'length': 1.136815696279914,
#    'lines': 30,
#    'pesssure_avg': 0.1248645782470702}],
#  [{'length': 2.015653678093531,
#    'lines': 31,
#    'pesssure_avg': 0.47032882273197196}],
#  [{'length': 29.910509602813875,
#    'lines': 32,
#    'pesssure_avg': 0.5816412057195393}],
#  [{'length': 72.88764450422036,
#    'lines': 33,
#    'pesssure_avg': 0.7697840809822083}],
#  [{'length': 0.7316034714389621,
#    'lines': 34,
#    'pesssure_avg': 0.209460593760014}],
#  [{'length': 1.9548872396657484,
#    'lines': 35,
#    'pesssure_avg': 0.2606088370084765}],
#  [{'length': 3.3414516765331523,
#    'lines': 36,
#    'pesssure_avg': 0.5735774755477905}],
#  [{'length': 1.9718374462281492,
#    'lines': 37,
#    'pesssure_avg': 0.8021210134029385}],
#  [{'length': 3.042567831157553,
#    'lines': 38,
#    'pesssure_avg': 0.8498512208461765}],
#  [{'length': 4.565991501638207,
#    'lines': 39,
#    'pesssure_avg': 0.9104804197947184}],
#  [{'length': 17.604113957169474,
#    'lines': 40,
#    'pesssure_avg': 0.9555168986320494}],
#  [{'length': 39.016451672778466,
#    'lines': 41,
#    'pesssure_avg': 0.9988525182008743}],
#  [{'length': 0.6926600734160985, 'lines': 42, 'pesssure_avg': 1.0}],
#  [{'length': 0.9212082448491106, 'lines': 43, 'pesssure_avg': 1.0}],
#  [{'length': 64.87357890975404,
#    'lines': 44,
#    'pesssure_avg': 0.9347571195700229}],
#  [{'length': 1.437459346396475,
#    'lines': 45,
#    'pesssure_avg': 0.6465603510538737}],
#  [{'length': 1.646055161400779,
#    'lines': 46,
#    'pesssure_avg': 0.6650339663028719}],
#  [{'length': 5.45289774458665,
#    'lines': 47,
#    'pesssure_avg': 0.7403524816036223}],
#  [{'length': 21.41616620449343,
#    'lines': 48,
#    'pesssure_avg': 0.784495656306927}],
#  [{'length': 12.097331117188865,
#    'lines': 49,
#    'pesssure_avg': 0.7944304570555688}],
#  [{'length': 7.590242428829421,
#    'lines': 50,
#    'pesssure_avg': 0.7982147037982937}],
#  [{'length': 1.3944279139174647,
#    'lines': 51,
#    'pesssure_avg': 0.779863178730011}],
#  [{'length': 0.9331724895346228,
#    'lines': 52,
#    'pesssure_avg': 0.38670939207077004}]]
# None

# %%
image= Image.open("C:\\Users\\hila\\Desktop\\train\\train\\7558\\SimpleTest\\1.png")
print("checking if the answers i did was right")
image
# Out:
# checking if the answers i did was right
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1381x925 at 0x1B6A24EAD30>

# %%
print("there is one line")
# Out:
# there is one line
